# %% [markdown]
# ## DATA PREPROCESSING AND DATA CLEANING

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('cyber.csv')
df.tail()
# Out:
#         Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  Bwd_Packet_Length_Max  \
# 138390                    32.0                    0.0                     60
# 138391                    41.0                    0.0                     41
# 138392                    43.0                    0.0                     97
# 138393                    47.0                    0.0                     63
# 138394                    34.0                    0.0                     79
#
#         Bwd_Packet_Length_Min  Bwd_Packet_Length_Mean  Bwd_Packet_Length_Std  \
# 138390                     60                    60.0                    0.0
# 138391                     41                    41.0                    0.0
# 138392                     97                    97.0                    0.0
# 138393                     63                    63.0                    0.0
# 138394                     79                    79.0                    0.0
#
# ...

# %%
df.shape
# Out:
# (138395, 43)

# %%
df.size
# Out:
# 5950985

# %%
df.columns
# Out:
# Index(['Fwd_Packet_Length_Mean', 'Fwd_Packet_Length_Std',
#        'Bwd_Packet_Length_Max', 'Bwd_Packet_Length_Min',
#        'Bwd_Packet_Length_Mean', 'Bwd_Packet_Length_Std', 'Fwd_IAT_Total',
#        'Fwd_IAT_Mean', 'Fwd_IAT_Std', 'Fwd_IAT_Max', 'Fwd_IAT_Min',
#        'Bwd_IAT_Total', 'Bwd_IAT_Mean', 'Bwd_IAT_Std', 'Bwd_IAT_Max',
#        'Fwd_PSH_Flags', 'Fwd_URG_Flags', 'Fwd_Header_Length',
#        'Bwd_Header_Length', 'Fwd_Packets/s', 'Bwd_Packets/s',
#        'Packet_Length_Std', 'Packet_Length_Variance', 'CWR_Flag_Count',
#        'Fwd_Packet/Bulk_Avg', 'Fwd_Bulk_Rate_Avg', 'Bwd_Bytes/Bulk_Avg',
#        'Bwd_Packet/Bulk_Avg', 'Bwd_Bulk_Rate_Avg', 'Subflow_Fwd_Packets',
#        'Subflow_Fwd_Bytes', 'Subflow_Bwd_Packets', 'Subflow_Bwd_Bytes',
#        'FWD_Init_Win_Bytes', 'Bwd_Init_Win_Bytes', 'Fwd_Act_Data_Pkts',
#        'Fwd_Seg_Size_Min', 'Active_Mean', 'Active_Std', 'Active_Max',
#        'Active_Min', 'Label', 'Connection_Type'],
#       dtype='object')

# %%
df.isnull()
# Out:
#         Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  Bwd_Packet_Length_Max  \
# 0                        False                  False                  False
# 1                        False                  False                  False
# 2                        False                  False                  False
# 3                        False                  False                  False
# 4                        False                  False                  False
# ...                        ...                    ...                    ...
# 138390                   False                  False                  False
# 138391                   False                  False                  False
# 138392                   False                  False                  False
# 138393                   False                  False                  False
# 138394                   False                  False                  False
#
# ...

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#        Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  Bwd_Packet_Length_Max  \
# count           138395.000000          138395.000000          138395.000000
# mean                20.518853              22.211238              57.723856
# std                120.279917             221.722094             580.275784
# min                  0.000000               0.000000               0.000000
# 25%                  0.000000               0.000000               0.000000
# 50%                  0.000000               0.000000               0.000000
# 75%                  6.000000               0.000000               0.000000
# max               8534.697356            7241.921811           61560.000000
#
#        Bwd_Packet_Length_Min  Bwd_Packet_Length_Mean  Bwd_Packet_Length_Std  \
# count          138395.000000           138395.000000          138395.000000
# mean                9.395202               20.238152              15.665406
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138395 entries, 0 to 138394
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Fwd_Packet_Length_Mean  138395 non-null  float64
#  1   Fwd_Packet_Length_Std   138395 non-null  float64
#  2   Bwd_Packet_Length_Max   138395 non-null  int64
#  3   Bwd_Packet_Length_Min   138395 non-null  int64
#  4   Bwd_Packet_Length_Mean  138395 non-null  float64
#  5   Bwd_Packet_Length_Std   138395 non-null  float64
#  6   Fwd_IAT_Total           138395 non-null  int64
#  7   Fwd_IAT_Mean            138395 non-null  float64
#  8   Fwd_IAT_Std             138395 non-null  float64
#  9   Fwd_IAT_Max             138395 non-null  int64
#  10  Fwd_IAT_Min             138395 non-null  int64
#  11  Bwd_IAT_Total           138395 non-null  int64
#  12  Bwd_IAT_Mean            138395 non-null  float64
#  13  Bwd_IAT_Std             138395 non-null  float64
# ...

# %%
df['Label'].unique()
# Out:
# array(['Benign', 'DNS Flood', 'ICMP Flood', 'OS Scan', 'Ping Sweep',
#        'Port Scan', 'SYN Flood', 'Slowloris', 'UDP Flood'], dtype=object)

# %%
df['Label'].value_counts()
# Out:
# Label
# Benign        20000
# ICMP Flood    20000
# OS Scan       20000
# Ping Sweep    20000
# Port Scan     20000
# Slowloris     18643
# SYN Flood     13857
# DNS Flood      5104
# UDP Flood       791
# Name: count, dtype: int64

# %%
pd.Categorical(df["Label"]).describe()
# Out:
#             counts     freqs
# categories
# Benign       20000  0.144514
# DNS Flood     5104  0.036880
# ICMP Flood   20000  0.144514
# OS Scan      20000  0.144514
# Ping Sweep   20000  0.144514
# Port Scan    20000  0.144514
# SYN Flood    13857  0.100126
# Slowloris    18643  0.134709
# UDP Flood      791  0.005716

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 138390    False
# 138391    False
# 138392    False
# 138393    False
# 138394    False
# Length: 138395, dtype: bool

# %%
df = df.drop_duplicates()

# %%
sum(df.duplicated())
# Out:
# 0
